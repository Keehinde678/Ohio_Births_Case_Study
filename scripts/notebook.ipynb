# %% [markdown]
# ## Import Libraries and load the CSV files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
birth_path = pd.read_csv(r"C:\Users\kehin\Downloads\OhioBirths.csv")
demographic = pd.read_csv(r"C:\Users\kehin\Downloads\OhioDemographics.csv")
# Out:
# C:\Users\kehin\AppData\Local\Temp\ipykernel_35252\3543685694.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   birth_path = pd.read_csv(r"C:\Users\kehin\Downloads\OhioBirths.csv")

# %% [markdown]
# # Clean and normalize counties

# %%
# function to standardize county names
def normalize_county(x):
    return str(x).strip().lower().replace("county","").replace(".","").replace(",","")
    births['county_l'] = births['county_of_birth'].apply(normalize_county)
demographic['county_l'] = demographic['County'].apply(normalize_county)

# %% [markdown]
# # Convert low_birth_weight to Binary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
birth_path = pd.read_csv(r"C:\Users\kehin\Downloads\OhioBirths.csv")
births['low_birth_weight_bin'] = births['low_birth_weight'].apply(
    lambda x:1 if str(x).strip().lower()in['1','yes','y','true','t'] else
    0 if str(x).strip().lower() in ['0', 'no', 'n', 'false', 'f'] else np.nan
)
births['age_of_mother'] = pd.to_numeric(births['age_of_mother'],
errors='coerce')
# Out:
# C:\Users\kehin\AppData\Local\Temp\ipykernel_35252\4258187500.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   birth_path = pd.read_csv(r"C:\Users\kehin\Downloads\OhioBirths.csv")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       5 import plotly.express as px
#       6 birth_path = pd.read_csv(r"C:\Users\kehin\Downloads\OhioBirths.csv")
# ----> 7 births['low_birth_weight_bin'] = births['low_birth_weight'].apply(
#       8     lambda x:1 if str(x).strip().lower()in['1','yes','y','true','t'] else
#       9     0 if str(x).strip().lower() in ['0', 'no', 'n', 'false', 'f'] else np.nan
#      10 )
#      11 births['age_of_mother'] = pd.to_numeric(births['age_of_mother'],
#      12 errors='coerce')
#
# NameError: name 'births' is not defined
